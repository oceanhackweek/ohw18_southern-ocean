# %%
# %matplotlib inline
import xarray as xr
import netCDF4 as nc
from glob import glob
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.feature as cfeature
import numpy as np

# %%
projection = ccr.PlateCarree()

# %%
traj_files = glob('./traj_data/*')
traj_files
# Out:
# ['./traj_data/9096SOOCN_HRQC.nc',
#  './traj_data/9091SOOCN_HRQC.nc',
#  './traj_data/9668SOOCN_HRQC.nc',
#  './traj_data/12734SOOCN_HRQC.nc',
#  './traj_data/9018SOOCN_HRQC.nc',
#  './traj_data/12742SOOCN_HRQC.nc',
#  './traj_data/12702SOOCN_HRQC.nc',
#  './traj_data/12757SOOCN_HRQC.nc',
#  './traj_data/9265SOOCN_HRQC.nc',
#  './traj_data/12381SOOCN_HRQC.nc',
#  './traj_data/12379SOOCN_HRQC.nc',
#  './traj_data/12386SOOCN_HRQC.nc',
#  './traj_data/12549SOOCN_HRQC.nc',
#  './traj_data/8514SOOCN_HRQC.nc',
#  './traj_data/12551SOOCN_HRQC.nc',
#  './traj_data/9762SOOCN_HRQC.nc',
#  './traj_data/9655SOOCN_HRQC.nc',
#  './traj_data/9600SOOCN_HRQC.nc',
#  './traj_data/8501SOOCN_HRQC.nc',
#  './traj_data/12543SOOCN_HRQC.nc',
#  './traj_data/9652SOOCN_HRQC.nc',
#  './traj_data/12709SOOCN_HRQC.nc',
#  './traj_data/9631SOOCN_HRQC.nc',
#  './traj_data/12575SOOCN_HRQC.nc',
#  './traj_data/12361SOOCN_HRQC.nc',
#  './traj_data/12366SOOCN_HRQC.nc',
#  './traj_data/12542SOOCN_HRQC.nc',
#  './traj_data/12545SOOCN_HRQC.nc',
#  './traj_data/9125SOOCN_HRQC.nc',
#  './traj_data/9646SOOCN_HRQC.nc',
#  './traj_data/12748SOOCN_HRQC.nc',
#  './traj_data/9101SOOCN_HRQC.nc',
#  './traj_data/12779SOOCN_HRQC.nc',
#  './traj_data/12781SOOCN_HRQC.nc',
#  './traj_data/9637SOOCN_HRQC.nc',
#  './traj_data/9662SOOCN_HRQC.nc',
#  './traj_data/12573SOOCN_HRQC.nc',
#  './traj_data/9031SOOCN_HRQC.nc',
#  './traj_data/12552SOOCN_HRQC.nc',
#  './traj_data/12784SOOCN_HRQC.nc',
#  './traj_data/9757SOOCN_HRQC.nc',
#  './traj_data/9750SOOCN_HRQC.nc',
#  './traj_data/12769SOOCN_HRQC.nc',
#  './traj_data/12370SOOCN_HRQC.nc',
#  './traj_data/9632SOOCN_HRQC.nc',
#  './traj_data/9099SOOCN_HRQC.nc',
#  './traj_data/12388SOOCN_HRQC.nc',
#  './traj_data/9660SOOCN_HRQC.nc',
#  './traj_data/9645SOOCN_HRQC.nc',
#  './traj_data/9650SOOCN_HRQC.nc',
#  './traj_data/12541SOOCN_HRQC.nc',
#  './traj_data/9602SOOCN_HRQC.nc',
#  './traj_data/9657SOOCN_HRQC.nc',
#  './traj_data/9634SOOCN_HRQC.nc',
#  './traj_data/9666SOOCN_HRQC.nc',
#  './traj_data/9744SOOCN_HRQC.nc',
#  './traj_data/12371SOOCN_HRQC.nc',
#  './traj_data/12782SOOCN_HRQC.nc',
#  './traj_data/12537SOOCN_HRQC.nc',
#  './traj_data/12363SOOCN_HRQC.nc',
#  './traj_data/9260SOOCN_HRQC.nc',
#  './traj_data/12730SOOCN_HRQC.nc',
#  './traj_data/9275SOOCN_HRQC.nc',
#  './traj_data/9095SOOCN_HRQC.nc',
#  './traj_data/9092SOOCN_HRQC.nc',
#  './traj_data/9749SOOCN_HRQC.nc',
#  './traj_data/12701SOOCN_HRQC.nc',
#  './traj_data/12741SOOCN_HRQC.nc',
#  './traj_data/12559SOOCN_HRQC.nc',
#  './traj_data/12736SOOCN_HRQC.nc',
#  './traj_data/12382SOOCN_HRQC.nc',
#  './traj_data/9094SOOCN_HRQC.nc',
#  './traj_data/12390SOOCN_HRQC.nc',
#  './traj_data/12558SOOCN_HRQC.nc',
#  './traj_data/12755SOOCN_HRQC.nc']

# %%
ds['Lat'].values
# Out:
# array([-67.005, -67.124, -67.129, -66.615, -66.981, -67.891, -68.213,
#        -68.011, -68.095, -68.271, -67.931, -67.458, -67.519, -67.681,
#        -67.802, -68.058, -68.315, -68.274, -68.233, -68.193, -68.152,
#        -68.112, -68.071, -68.031, -67.99 , -67.949, -67.908, -67.867,
#        -67.827, -67.787, -67.746, -67.706, -67.665, -67.624, -67.584,
#        -67.602, -67.997, -68.103, -68.179, -68.382, -68.588, -68.576,
#        -68.28 , -68.089, -68.758, -68.954])

# %%
ds['Lon'].values
# Out:
# array([257.001, 257.048, 255.819, 255.404, 255.874, 255.528, 255.493,
#        257.306, 257.074, 259.947, 260.089, 258.797, 256.504, 254.723,
#        254.287, 254.413, 254.54 , 254.503, 254.466, 254.429, 254.392,
#        254.356, 254.319, 254.282, 254.246, 254.208, 254.171, 254.135,
#        254.098, 254.061, 254.025, 253.988, 253.951, 253.915, 253.878,
#        255.339, 254.99 , 254.621, 254.245, 254.022, 254.165, 255.04 ,
#        257.391, 260.313, 262.422, 259.859])

# %%
fig = plt.figure()
fig.set_size_inches(10,7)
ax = plt.axes(projection=ccrs.Robinson())
# ax.gridlines(draw_labels=True, zorder= 20)
extent = (-180, -0, 90, -90)
ax.set_extent(extent)
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
for f in traj_files:
    ds = xr.open_dataset(f)
    ax.scatter(ds['Lon'].values - 360, ds['Lat'].values, transform=ccrs.Geodetic(), s=5)
# Out:
# //anaconda/lib/python3.5/site-packages/xarray/coding/variables.py:135: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv

# %%
lats = []
for f in traj_files:
    ds = xr.open_dataset(f)
    lats.append(np.max(ds['Lat'].values))
# Out:
# //anaconda/lib/python3.5/site-packages/xarray/coding/variables.py:135: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv

# %%
np.max(lats)
# Out:
# -38.297
